# %%
import pandas as pd

# %%
import numpy as np

# %%
print('hello world')
# Out:
# hello world

# %%
book = pd.read_csv("03_Library Systembook.csv")

# %%
customers = pd.read_csv("03_Library SystemCustomers.csv")

# %%
book.head(25)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
book["Book checkout"]= book["Book checkout"].str.strip().str.strip('"')

# %%
book["Book checkout"]= pd.to_datetime(book["Book checkout"],dayfirst = True, errors = "coerce")

# %%
book.head(25)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     2023-02-20
# 1    2.0          Lord of the rings the two towers    2023-03-24
# 2    3.0  Lord of the rings the return of the kind    2023-03-29
# 3    4.0                                The hobbit    2023-04-02
# 4    5.0                                     Dune     2023-04-02
# 5    6.0                              Little Women    2023-04-02
# 6    7.0                                        IT    2063-04-10
# 7    8.0                                   Misery     2023-04-15
# 8    9.0                                  Catch 22    2023-04-15
# 9   10.0                              Animal Farm     2023-04-20
# 10  11.0                                      1984    2023-04-23
# 11  12.0                              Little Women    2023-04-02
# 12  13.0                              East of Eden    2023-04-30
# ...

# %%
books_silver = book[book["Customer ID"].notna()]

# %%
display(customers)
# Out:
#    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 3          NaN               NaN
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted

# %%
display(books_silver)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     2023-02-20
# 1    2.0          Lord of the rings the two towers    2023-03-24
# 2    3.0  Lord of the rings the return of the kind    2023-03-29
# 3    4.0                                The hobbit    2023-04-02
# 4    5.0                                     Dune     2023-04-02
# 5    6.0                              Little Women    2023-04-02
# 6    7.0                                        IT    2063-04-10
# 7    8.0                                   Misery     2023-04-15
# 8    9.0                                  Catch 22    2023-04-15
# 9   10.0                              Animal Farm     2023-04-20
# 10  11.0                                      1984    2023-04-23
# 11  12.0                              Little Women    2023-04-02
# 12  13.0                              East of Eden    2023-04-30
# ...

# %%
customers_silver  = customers[customers["Customer ID"].notna()]

# %%
display(customers_silver)
# Out:
#    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted

# %%
books_silver["Book Returned"]= pd.to_datetime(books_silver["Book Returned"],dayfirst = True, errors = "coerce")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11972\3184760469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books_silver["Book Returned"]= pd.to_datetime(books_silver["Book Returned"],dayfirst = True, errors = "coerce")

# %%
customers_silver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID    8 non-null      float64
#  1   Customer Name  8 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 192.0+ bytes

# %%
books_silver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      20 non-null     float64
#  1   Books                   20 non-null     object
#  2   Book checkout           19 non-null     datetime64[ns]
#  3   Book Returned           20 non-null     datetime64[ns]
#  4   Days allowed to borrow  20 non-null     object
#  5   Customer ID             20 non-null     float64
# dtypes: datetime64[ns](2), float64(2), object(2)
# memory usage: 1.1+ KB

# %%
def dataEnrich(df, col1, col2, new_col="days_between"):
    df = df.copy()
    df[new_col] = (df[col2] - df[col1]).dt.days
    return df

# %%
def duplicateCheck(df,subset = None):
    n_dupes = df.duplicayed(subset = subset).sum()
    dupes = df[df.duplicated(subset = subset)].sum()
    print(f"{n_dupes} duplicate row(s) would be removed: "
          f"{len(dupes)} row(s) involved in duplicate groups.")
    
    return dupes.sort_values(by=subset) if subset else dupes
